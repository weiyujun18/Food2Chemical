# %%
import pandas as pd
from pyomo.environ import *

# %% [markdown]
# CN_file

# %%
# Read the excel file into a pandas DataFrame, change the file path to your own
file_name_FL2CH_CN = "C:\\Workspace\\Food_lost2Ch\\IO\\FL2CH_CN.xlsx"

# eta is yield
eta_df = pd.read_excel(file_name_FL2CH_CN, sheet_name = 'eta', index_col=0)

# FL is the qty of each Food loss or by-products stream
FL_df=pd.read_excel(file_name_FL2CH_CN, sheet_name = 'FL')

# CH is the demand qty of each platform chemical
CH_df=pd.read_excel(file_name_FL2CH_CN, sheet_name = 'CH')
# profit is the profit of each platform chemical
profit_df=pd.read_excel(file_name_FL2CH_CN, sheet_name = 'profit')
# GWP is the global warming potential saving of each platform chemical
GWP_df=pd.read_excel(file_name_FL2CH_CN, sheet_name = 'GWP')

# %% [markdown]
# US_file

# %%
# # Read the excel file into a pandas DataFrame, change the file path to your own
# file_name_FL2CH_US = "C:\\Workspace\\Food_lost2Ch\\IO\\FL2CH_US.xlsx"

# # eta is yield
# eta_df = pd.read_excel(file_name_FL2CH_US, sheet_name = 'eta', index_col=0)

# # FL is the qty of each Food loss or by-products stream
# FL_df=pd.read_excel(file_name_FL2CH_US, sheet_name = 'FL')

# # CH is the demand qty of each platform chemical
# CH_df=pd.read_excel(file_name_FL2CH_US, sheet_name = 'CH')
# # profit is the profit of each platform chemical
# profit_df=pd.read_excel(file_name_FL2CH_US, sheet_name = 'profit')
# # GWP is the global warming potential saving of each platform chemical
# GWP_df=pd.read_excel(file_name_FL2CH_US, sheet_name = 'GWP')

# %% [markdown]
# EU_file

# %%
# # Read the excel file into a pandas DataFrame, change the file path to your own
# file_name_FL2CH_EU = "C:\\Workspace\\Food_lost2Ch\\IO\\FL2CH_EU.xlsx"

# # eta is yield
# eta_df = pd.read_excel(file_name_FL2CH_EU, sheet_name = 'eta', index_col=0)

# # FL is the qty of each Food loss or by-products stream
# FL_df=pd.read_excel(file_name_FL2CH_EU, sheet_name = 'FL')

# # CH is the demand qty of each platform chemical
# CH_df=pd.read_excel(file_name_FL2CH_EU, sheet_name = 'CH')
# # profit is the profit of each platform chemical
# profit_df=pd.read_excel(file_name_FL2CH_EU, sheet_name = 'profit')
# # GWP is the global warming potential saving of each platform chemical
# GWP_df=pd.read_excel(file_name_FL2CH_EU, sheet_name = 'GWP')

# %%
# Convert the DataFrame to a dictionary
eta_dict = eta_df.to_dict(orient='index')
FL_dict = FL_df['Column1'].to_dict()
CH_dict = CH_df['Column1'].to_dict()
profit_dict = profit_df['Column1'].to_dict()
GWP_dict = GWP_df['Column1'].to_dict()

# Convert nested dictionary format for Pyomo
eta_dict = {(row, col): value for row, row_data in eta_dict.items() for col, value in row_data.items()}
FL_dict = {i+1: FL_dict[i] for i in FL_dict}
CH_dict = {i+1: CH_dict[i] for i in CH_dict}
profit_dict = {i+1: profit_dict[i] for i in profit_dict}
GWP_dict = {i+1: GWP_dict[i] for i in GWP_dict}

print(GWP_dict)
# Out:
# {1: 1422903.4852546917, 2: 0.0, 3: 8033410.0, 4: 0.0, 5: 7414999.999999999, 6: 6918300.0, 7: 1480560.0000000002, 8: 0.0, 9: 3792999.9999999995, 10: 1833999.9999999998, 11: 1789999.9999999998}

# %%
# Create a Concrete Model
model = ConcreteModel()

# Sets
model.I = RangeSet(1, 22) # for CN, (1, 22), for US (1, 13), for EU (1, 19)
model.J = RangeSet(1, 11)


# Parameters
model.FL = Param(model.I, initialize=FL_dict) 
model.CH = Param(model.J, initialize=CH_dict)     

model.eta = Param(model.I, model.J, initialize=eta_dict)

#option 1: model profit,choose this option when run the objective function 1
model.profit = Param(model.J, initialize=profit_dict)  
# # option 2: model GWP, choose this option when run the objective function 2
# model.GWP = Param(model.J, initialize=GWP_dict)

# Variables
model.x = Var(model.I, within=NonNegativeReals)
model.y = Var(model.J, within=NonNegativeReals)
model.w = Var(model.I, model.J, within=NonNegativeReals) # w[i,j] indicate the FL[i] used to produce CH[j]

# option 1: Objective function 1, profit
def objective_rule(model):
    return sum(model.y[j] * model.profit[j] for j in model.J)

# # option 2: Objective function 2, GWP
# def objective_rule(model):
#     return sum(model.y[j] * model.GWP[j] for j in model.J)

model.obj = Objective(rule=objective_rule, sense=maximize)

# Constraints
def x_constraint_rule(model, i):
    return model.x[i] == sum(model.w[i, j] for j in model.J)

model.x_constraint = Constraint(model.I, rule=x_constraint_rule)

def y_constraint_rule(model, j):
    return model.y[j] == sum(model.w[i, j] * model.eta[i, j] for i in model.I)

model.y_constraint = Constraint(model.J, rule=y_constraint_rule)

def y_demand_constraint_rule(model, j):
    return model.y[j] <= model.CH[j]

model.y_demand_constraint = Constraint(model.J, rule=y_demand_constraint_rule)

def x_fleet_constraint_rule(model, i):
    return model.x[i] <= model.FL[i]

model.x_fleet_constraint = Constraint(model.I, rule=x_fleet_constraint_rule)


# To solve the model, you would typically use a solver

# Solve the model
solvername='glpk'
solverpath_folder='C:\Python311\winglpk\glpk-4.65\w64' #does not need to be directly on c drive
solverpath_exe='C:\Python311\winglpk\glpk-4.65\w64\glpsol.exe' #does not need to be directly on c drive
# solver = SolverFactory('glpk')

solver=SolverFactory(solvername,executable=solverpath_exe)

results = solver.solve(model)

# Display the results
model.display()
# Out:
# Model unknown
#
#   Variables:
#     x : Size=22, Index=I
#         Key : Lower : Value            : Upper : Fixed : Stale : Domain
#           1 :     0 : 10144.2341500138 :  None : False : False : NonNegativeReals
#           2 :     0 :              0.0 :  None : False : False : NonNegativeReals
#           3 :     0 :              0.0 :  None : False : False : NonNegativeReals
#           4 :     0 :              0.0 :  None : False : False : NonNegativeReals
#           5 :     0 : 7749.54423606489 :  None : False : False : NonNegativeReals
#           6 :     0 :              0.0 :  None : False : False : NonNegativeReals
#           7 :     0 : 5.42237325058413 :  None : False : False : NonNegativeReals
#           8 :     0 : 8127.25450901804 :  None : False : False : NonNegativeReals
#           9 :     0 :  495.63502063146 :  None : False : False : NonNegativeReals
#          10 :     0 : 707.654281879175 :  None : False : False : NonNegativeReals
#          11 :     0 : 2201.09800924474 :  None : False : False : NonNegativeReals
#          12 :     0 :            385.5 :  None : False : False : NonNegativeReals
#          13 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          14 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          15 :     0 : 2566.19786336811 :  None : False : False : NonNegativeReals
#          16 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          17 :     0 : 3808.22792120847 :  None : False : False : NonNegativeReals
#          18 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          19 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          20 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          21 :     0 :              0.0 :  None : False : False : NonNegativeReals
#          22 :     0 :              0.0 :  None : False : False : NonNegativeReals
#     y : Size=11, Index=J
#         Key : Lower : Value             : Upper : Fixed : Stale : Domain
#           1 :     0 :      2747.7534108 :  None : False : False : NonNegativeReals
#           2 :     0 :            405.55 :  None : False : False : NonNegativeReals
#           3 :     0 :   3.2258064516129 :  None : False : False : NonNegativeReals
#           4 :     0 :  83.9010212097408 :  None : False : False : NonNegativeReals
#           5 :     0 :   466.21387283237 :  None : False : False : NonNegativeReals
#           6 :     0 :            139.09 :  None : False : False : NonNegativeReals
#           7 :     0 : 0.268019776216497 :  None : False : False : NonNegativeReals
#           8 :     0 :  1.41097046413502 :  None : False : False : NonNegativeReals
#           9 :     0 :           253.953 :  None : False : False : NonNegativeReals
#          10 :     0 :             866.0 :  None : False : False : NonNegativeReals
#          11 :     0 :             33.25 :  None : False : False : NonNegativeReals
#     w : Size=242, Index=I*J
#         Key      : Lower : Value            : Upper : Fixed : Stale : Domain
#           (1, 1) :     0 : 8077.45417702642 :  None : False : False : NonNegativeReals
#           (1, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (1, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (1, 10) :     0 : 2066.77997298734 :  None : False : False : NonNegativeReals
#          (1, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (2, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (2, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (2, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (3, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (3, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (3, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (4, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (4, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (4, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 5) :     0 : 7749.54423606489 :  None : False : False : NonNegativeReals
#           (5, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (5, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (5, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (5, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (6, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (6, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (6, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 7) :     0 : 5.42237325058413 :  None : False : False : NonNegativeReals
#           (7, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (7, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (7, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (7, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 2) :     0 : 8127.25450901804 :  None : False : False : NonNegativeReals
#           (8, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (8, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (8, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (8, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#           (9, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (9, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (9, 11) :     0 :  495.63502063146 :  None : False : False : NonNegativeReals
#          (10, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (10, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (10, 3) :     0 : 17.8050736996157 :  None : False : False : NonNegativeReals
#          (10, 4) :     0 : 347.786705340329 :  None : False : False : NonNegativeReals
#          (10, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (10, 6) :     0 : 337.009788554055 :  None : False : False : NonNegativeReals
#          (10, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (10, 8) :     0 : 5.05271428517465 :  None : False : False : NonNegativeReals
#          (10, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (10, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (10, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (11, 9) :     0 : 2201.09800924474 :  None : False : False : NonNegativeReals
#         (11, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (11, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 1) :     0 :            385.5 :  None : False : False : NonNegativeReals
#          (12, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (12, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (12, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (12, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (13, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (13, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (13, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (14, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (14, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (14, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 1) :     0 : 2566.19786336811 :  None : False : False : NonNegativeReals
#          (15, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (15, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (15, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (15, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (16, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (16, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (16, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 1) :     0 : 3808.22792120847 :  None : False : False : NonNegativeReals
#          (17, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (17, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (17, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (17, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (18, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (18, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (18, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (19, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (19, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (19, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (20, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (20, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (20, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (21, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (21, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (21, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 1) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 2) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 3) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 4) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 5) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 6) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 7) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 8) :     0 :              0.0 :  None : False : False : NonNegativeReals
#          (22, 9) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (22, 10) :     0 :              0.0 :  None : False : False : NonNegativeReals
#         (22, 11) :     0 :              0.0 :  None : False : False : NonNegativeReals
#
#   Objectives:
#     obj : Size=1, Index=None, Active=True
#         Key  : Active : Value
#         None :   True : 27092387898.712975
#
#   Constraints:
#     x_constraint : Size=22
#         Key : Lower : Body                  : Upper
#           1 :   0.0 : 4.001776687800884e-11 :   0.0
#           2 :   0.0 :                   0.0 :   0.0
#           3 :   0.0 :                   0.0 :   0.0
#           4 :   0.0 :                   0.0 :   0.0
#           5 :   0.0 :                   0.0 :   0.0
#           6 :   0.0 :                   0.0 :   0.0
#           7 :   0.0 :                   0.0 :   0.0
#           8 :   0.0 :                   0.0 :   0.0
#           9 :   0.0 :                   0.0 :   0.0
#          10 :   0.0 : 6.821210263296962e-13 :   0.0
#          11 :   0.0 :                   0.0 :   0.0
#          12 :   0.0 :                   0.0 :   0.0
#          13 :   0.0 :                   0.0 :   0.0
#          14 :   0.0 :                   0.0 :   0.0
#          15 :   0.0 :                   0.0 :   0.0
#          16 :   0.0 :                   0.0 :   0.0
#          17 :   0.0 :                   0.0 :   0.0
#          18 :   0.0 :                   0.0 :   0.0
#          19 :   0.0 :                   0.0 :   0.0
#          20 :   0.0 :                   0.0 :   0.0
#          21 :   0.0 :                   0.0 :   0.0
#          22 :   0.0 :                   0.0 :   0.0
#     y_constraint : Size=11
#         Key : Lower : Body                    : Upper
#           1 :   0.0 :                     0.0 :   0.0
#           2 :   0.0 : -1.7053025658242404e-13 :   0.0
#           3 :   0.0 : -3.1086244689504383e-15 :   0.0
#           4 :   0.0 :  1.5631940186722204e-13 :   0.0
#           5 :   0.0 :  2.2737367544323206e-13 :   0.0
#           6 :   0.0 :  -2.842170943040401e-14 :   0.0
#           7 :   0.0 :  -6.661338147750939e-16 :   0.0
#           8 :   0.0 :  -8.881784197001252e-16 :   0.0
#           9 :   0.0 :   4.831690603168681e-13 :   0.0
#          10 :   0.0 :  1.7053025658242404e-12 :   0.0
#          11 :   0.0 :  -7.105427357601002e-15 :   0.0
#     y_demand_constraint : Size=11
#         Key : Lower : Body              : Upper
#           1 :  None :      2747.7534108 :  2747.7534107999995
#           2 :  None :            405.55 :              405.55
#           3 :  None :   3.2258064516129 :  3.2258064516129035
#           4 :  None :  83.9010212097408 :   83.90102120974078
#           5 :  None :   466.21387283237 :  466.21387283236993
#           6 :  None :            139.09 :              139.09
#           7 :  None : 0.268019776216497 : 0.26801977621649753
#           8 :  None :  1.41097046413502 :   1.410970464135021
#           9 :  None :           253.953 :             253.953
#          10 :  None :             866.0 :               866.0
#          11 :  None :             33.25 :               33.25
#     x_fleet_constraint : Size=22
#         Key : Lower : Body             : Upper
#           1 :  None : 10144.2341500138 : 10144.234150013763
#           2 :  None :              0.0 : 15996.665579128821
#           3 :  None :              0.0 :  38142.44190270038
#           4 :  None :              0.0 :  19071.22095135019
#           5 :  None : 7749.54423606489 :  8336.855481471332
#           6 :  None :              0.0 :   17385.9370767711
#           7 :  None : 5.42237325058413 :  2634.232890419864
#           8 :  None : 8127.25450901804 : 15189.616145848691
#           9 :  None :  495.63502063146 :            27000.0
#          10 :  None : 707.654281879175 :  2333.333333333333
#          11 :  None : 2201.09800924474 : 17582.681324205347
#          12 :  None :            385.5 :              385.5
#          13 :  None :              0.0 : 11944.664206825732
#          14 :  None :              0.0 :              351.0
#          15 :  None : 2566.19786336811 :  9236.688825688709
#          16 :  None :              0.0 :              180.0
#          17 :  None : 3808.22792120847 : 3808.2279212084695
#          18 :  None :              0.0 :  947.1054983699996
#          19 :  None :              0.0 : 1671.1685486993929
#          20 :  None :              0.0 : 490.65095234232047
#          21 :  None :              0.0 :  900.9087792323859
#          22 :  None :              0.0 :  510.2987647787995
